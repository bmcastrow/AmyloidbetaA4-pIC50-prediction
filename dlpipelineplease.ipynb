# %% [markdown]
# # Data Acquisition ⚛

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target # Search the organism or protein (can be done in chembl manually)
target_query = target.search("alzheimer")
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0                                                 []       Homo sapiens
# 1  [{'xref_id': 'Q92542', 'xref_name': None, 'xre...       Homo sapiens
# 2                                                 []       Homo sapiens
# 3                                                 []  Rattus norvegicus
# 4                                                 []       Mus musculus
# 5  [{'xref_id': 'P05067', 'xref_name': None, 'xre...       Homo sapiens
#
#                                    pref_name  score  species_group_flag  \
# 0  Nucleosome-remodeling factor subunit BPTF   13.0               False
# 1                                  Nicastrin   11.0               False
# 2                            Gamma-secretase   11.0               False
# 3                    Amyloid-beta A4 protein    9.0               False
# 4                    Amyloid-beta A4 protein    8.0               False
# 5                    Amyloid-beta A4 protein    7.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL3085621  [{'accession': 'Q12830', 'component_descriptio...
# 1       CHEMBL3418  [{'accession': 'Q92542', 'component_descriptio...
# 2    CHEMBL2094135  [{'accession': 'Q96BI3', 'component_descriptio...
# 3    CHEMBL3638365  [{'accession': 'P08592', 'component_descriptio...
# 4    CHEMBL4523942  [{'accession': 'P12023', 'component_descriptio...
# 5       CHEMBL2487  [{'accession': 'P05067', 'component_descriptio...
#
#        target_type  tax_id
# 0   SINGLE PROTEIN    9606
# 1   SINGLE PROTEIN    9606
# 2  PROTEIN COMPLEX    9606
# 3   SINGLE PROTEIN   10116
# 4   SINGLE PROTEIN   10090
# 5   SINGLE PROTEIN    9606

# %%
selected_target = targets.target_chembl_id[5] #bioactivity of Amyloid-beta A4 in human ( index 5 and gives the unique id of the target)
selected_target
# Out:
# 'CHEMBL2487'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type='IC50') ## Only bioactivity data for Amyloid-beta 4 that are reported as [IC50 values (nanomolar) - concentration of a substance that is required to inhibit a biological function by 50%.]

# %%
type(res)
# Out:
# chembl_webresource_client.query_set.QuerySet

# %%
#pd.set_option('display.max_columns', None)
#pd.set_option
df_bioactivity_data = pd.DataFrame.from_dict(res)
df_bioactivity_data
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1598  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1599  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1600  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1601  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1602  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0          357577                                                 []
# 1          357580                                                 []
# 2          358965                                                 []
# 3          368887                                                 []
# 4          375954                                                 []
# ...           ...                                                ...
# 1598     25079667  [{'comments': None, 'relation': '=', 'result_f...
# 1599     25079668  [{'comments': None, 'relation': '=', 'result_f...
# 1600     25079669  [{'comments': None, 'relation': '=', 'result_f...
# 1601     25079670  [{'comments': None, 'relation': '=', 'result_f...
# 1602     25079671  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 1       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 2       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 3       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 4       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# ...              ...                                                ...
# 1598   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1599   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1600   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1601   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1602   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1598          B                    None                   None  BAO_0000190
# 1599          B                    None                   None  BAO_0000190
# 1600          B                    None                   None  BAO_0000190
# 1601          B                    None                   None  BAO_0000190
# 1602          B                    None                   None  BAO_0000190
#
#       ... target_organism         target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 2     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 3     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 4     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# ...   ...             ...                      ...           ...        ...
# 1598  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1599  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1600  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1601  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1602  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
#
#       toid  type units    uo_units upper_value value
# 0     None  IC50    uM  UO_0000065        None   5.0
# 1     None  IC50    uM  UO_0000065        None   2.7
# 2     None  IC50    uM  UO_0000065        None   1.8
# 3     None  IC50    uM  UO_0000065        None  11.0
# 4     None  IC50    uM  UO_0000065        None  10.0
# ...    ...   ...   ...         ...         ...   ...
# 1598  None  IC50    uM  UO_0000065        None  1.03
# 1599  None  IC50    uM  UO_0000065        None  0.99
# 1600  None  IC50    uM  UO_0000065        None   0.1
# 1601  None  IC50    uM  UO_0000065        None  1.56
# 1602  None  IC50    uM  UO_0000065        None  0.18
#
# [1603 rows x 46 columns]

# %%
df_bioactivity_data.standard_type.unique() # check all IC50s
# Out:
# array(['IC50'], dtype=object)

# %%
df_bioactivity_data.standard_value.unique() #check the type they are strings
# Out:
# array(['5000.0', '2700.0', '1800.0', '11000.0', '10000.0', '305000.0',
#        '75000.0', None, '77000.0', '94000.0', '21000.0', '46000.0',
#        '129000.0', '83000.0', '67000.0', '210000.0', '41000.0', '35000.0',
#        '-1.0', '111000.0', '22000.0', '14000.0', '96300.0', '-5.0',
#        '101000.0', '70600.0', '31600.0', '409000.0', '33600.0', '57900.0',
#        '81000.0', '17700.0', '114000.0', '64000.0', '12000.0', '20000.0',
#        '280000.0', '6700.0', '5.2', '6000.0', '9900.0', '740.0', '180.0',
#        '200.0', '6800.0', '3000.0', '74.0', '30.0', '160.0', '17.0',
#        '152.0', '54.0', '29.0', '15.0', '530.0', '16.0', '140.0', '120.0',
#        '540.0', '450.0', '650.0', '600.0', '73.0', '60.0', '360.0',
#        '190.0', '900.0', '1000.0', '680.0', '880.0', '780.0', '1900.0',
#        '86.0', '280.0', '220.0', '0.3', '56.0', '47.0', '46.0', '14.0',
#        '12.0', '27.0', '3.5', '2.5', '2.8', '2.4', '81.0', '6.9', '9.6',
#        '25.0', '10.0', '13.0', '9.0', '28.0', '3.2', '104.0', '57.0',
#        '2425.0', '4.3', '39.0', '32.0', '144.0', '45.0', '20.0', '115.0',
#        '7.7', '8.3', '8000.0', '800.0', '100.0', '1100.0', '1300.0',
#        '300.0', '700.0', '1400.0', '1700.0', '500.0', '2300.0', '9690.0',
#        '810.0', '130.0', '1980.0', '470.0', '170.0', '70.0', '3620.0',
#        '3440.0', '2190.0', '3210.0', '1340.0', '2800.0', '820.0', '80.0',
#        '2950.0', '2160.0', '5440.0', '30000.0', '58.0', '19.0', '41.0',
#        '267.0', '85.0', '35.0', '182.0', '204.0', '185.0', '137.0',
#        '75.0', '66.0', '33.0', '22.0', '158.0', '395.0', '24.0', '44.0',
#        '124.0', '98.0', '3200.0', '2100.0', '3700.0', '3400.0', '1600.0',
#        '3300.0', '13000.0', '62000.0', '23000.0', '100000.0', '32800.0',
#        '92900.0', '16400.0', '4700.0', '2200.0', '1200.0', '48.7', '45.3',
#        '35.8', '30.2', '10.5', '25.7', '8.0', '13.8', '41.8', '102.0',
#        '4.0', '23.1', '32.5', '6500.0', '4000.0', '29000.0', '36000.0',
#        '15110.0', '12350.0', '18350.0', '10320.0', '13070.0', '7560.0',
#        '14160.0', '6510.0', '7060.0', '7870.0', '10220.0', '10660.0',
#        '12200.0', '19700.0', '15900.0', '18500.0', '23800.0', '12500.0',
#        '9700.0', '10200.0', '19100.0', '8400.0', '7800.0', '10500.0',
#        '10900.0', '5800.0', '13300.0', '10100.0', '7300.0', '8300.0',
#        '20100.0', '18900.0', '19900.0', '17800.0', '5900.0', '14600.0',
#        '13100.0', '28400.0', '50000.0', '43700.0', '7700.0', '5500.0',
#        '7400.0', '9500.0', '18100.0', '18400.0', '20300.0', '11500.0',
#        '12600.0', '4800.0', '14100.0', '9600.0', '13500.0', '13200.0',
#        '17300.0', '14900.0', '9800.0', '14200.0', '12800.0', '13700.0',
#        '16800.0', '6880.0', '4430.0', '4770.0', '6110.0', '3150.0',
#        '8180.0', '4830.0', '5930.0', '51000.0', '1540.0', '24200.0',
#        '93.0', '7.0', '18.0', '6.0', '123.0', '550.0', '410.0', '7100.0',
#        '1500.0', '380.0', '13400.0', '6100.0', '4600.0', '6400.0',
#        '5400.0', '250.0', '270.0', '210.0', '91.0', '110.0', '400.0',
#        '68.0', '1950.0', '2750.0', '95900.0', '28000.0', '34300.0',
#        '71900.0', '43500.0', '3110.0', '26000.0', '17000.0', '4300.0',
#        '15800.0', '2900.0', '3900.0', '15000.0', '8500.0', '3960.0',
#        '244300.0', '300000.0', '269500.0', '203700.0', '186600.0',
#        '27000.0', '5600.0', '14500.0', '19600.0', '3500.0', '5100.0',
#        '19500.0', '30300.0', '33000.0', '15300.0', '15100.0', '500000.0',
#        '75100.0', '55400.0', '10600.0', '11300.0', '7500.0', '40500.0',
#        '71.28', '22.54', '51.81', '45.29', '77.45', '55.86', '30.74',
#        '65.5', '37.36', '17.36', '49.14', '45.88', '46.12', '51.77',
#        '38.96', '12.21', '4100.0', '3100.0', '25000.0', '14700.0',
#        '8100.0', '5300.0', '13800.0', '22500.0', '8700.0', '14800.0',
#        '22300.0', '2600.0', '930.0', '13600.0', '580.0', '620.0',
#        '20600.0', '3600.0', '9000.0', '240000.0', '9200.0', '11750.0',
#        '10110.0', '21810.0', '2500.0', '610.0', '520.0', '760.0', '420.0',
#        '590.0', '920.0', '9470.0', '18250.0', '66360.0', '630.0',
#        '7940.0', '1.0', '440.0', '310.0', '560.0', '320.0', '2.0', '1.6',
#        '0.7', '96.0', '2.1', '678.0', '0.6', '216.0', '1.7', '986.0',
#        '4.8', '176.0', '0.8', '3.0', '7.4', '23.0', '118.0', '11.0',
#        '78.0', '3.1', '92.0', '4.5', '8.4', '0.9', '2.3', '1.5', '1.3',
#        '630000.0', '84000.0', '200000.0', '800000.0', '840.0', '49.0',
#        '82.0', '62.0', '88.0', '480.0', '1.4', '1.9', '6.6', '5.8',
#        '18.7', '5.5', '10.2', '6.4', '2.9', '12.9', '16.5', '66.6',
#        '10.1', '13.9', '228.0', '26.4', '57.7', '23.3', '9.5', '421.0',
#        '397.0', '79.0', '5.4', '18970.0', '19440.0', '29220.0', '23390.0',
#        '8940.0', '16500.0', '12480.0', '10720.0', '15380.0', '21760.0',
#        '11890.0', '18730.0', '26600.0', '25600.0', '24000.0', '48000.0',
#        '42000.0', '16700.0', '8200.0', '11900.0', '7200.0', '10400.0',
#        '11200.0', '14400.0', '7000.0', '4400.0', '5700.0', '6600.0',
#        '4900.0', '2000.0', '3800.0', '790.0', '124600.0', '176200.0',
#        '22700.0', '87800.0', '72900.0', '138.0', '10430.0', '11550.0',
#        '15890.0', '16290.0', '18310.0', '23540.0', '17850.0', '18550.0',
#        '20720.0', '17600.0', '18050.0', '22510.0', '5840.0', '8280.0',
#        '14990.0', '43600.0', '85500.0', '4500.0', '6200.0', '7900.0',
#        '9400.0', '12430.0', '8860.0', '18940.0', '11440.0', '5050.0',
#        '16810.0', '7350.0', '17330.0', '22550.0', '19740.0', '5640.0',
#        '18280.0', '20610.0', '45000.0', '17680.0', '5920.0', '7930.0',
#        '8290.0', '17950.0', '4200.0', '15600.0', '199.53', '17230.0',
#        '8065.0', '6385.0', '46420.0', '44520.0', '8900.0', '21700.0',
#        '17500.0', '3980.0', '3630.0', '2410.0', '3550.0', '3860.0',
#        '3450.0', '3050.0', '3710.0', '3160.0', '5470.0', '2370.0',
#        '2310.0', '3310.0', '45600.0', '21300.0', '17440.0', '3870.0',
#        '17890.0', '15720.0', '68000.0', '24700.0', '62700.0', '221000.0',
#        '29300.0', '150800.0', '12300.0', '148800.0', '12530.0', '34900.0',
#        '19710.0', '2050.0', '15120.0', '18300.0', '13430.0', '16250.0',
#        '7050.0', '5060.0', '2850.0', '1210.0', '1560.0', '1690.0',
#        '3260.0', '1620.0', '3090.0', '5270.0', '3270.0', '226230.0',
#        '24600.0', '39270.0', '34930.0', '119160.0', '12380.0', '79870.0',
#        '106820.0', '65090.0', '27940.0', '3850.0', '10640.0', '18650.0',
#        '45780.0', '78070.0', '17080.0', '18720.0', '17750.0', '19240.0',
#        '16830.0', '8590.0', '12780.0', '21830.0', '10550.0', '35670.0',
#        '3130.0', '8170.0', '81560.0', '3350.0', '4780.0', '3610.0',
#        '54210.0', '17910.0', '98460.0', '7760.0', '9910.0', '205460.0',
#        '98790.0', '45310.0', '2240.0', '4120.0', '5540.0', '3950.0',
#        '4510.0', '7010.0', '6260.0', '3290.0', '2570.0', '5320.0',
#        '6020.0', '5380.0', '6180.0', '2070.0', '7120.0', '8270.0',
#        '3560.0', '1480.0', '1490.0', '1270.0', '1030.0', '1320.0',
#        '1380.0', '1680.0', '3780.0', '3170.0', '53010.0', '68500.0',
#        '41160.0', '21920.0', '41150.0', '137390.0', '113130.0', '47810.0',
#        '167530.0', '115520.0', '136390.0', '117490.0', '55950.0',
#        '82410.0', '102590.0', '6560.0', '70480.0', '129540.0', '154420.0',
#        '153050.0', '129690.0', '4690.0', '8340.0', '7020.0', '7630.0',
#        '6300.0', '3910.0', '5090.0', '9270.0', '4260.0', '7370.0',
#        '6330.0', '3220.0', '40700.0', '51400.0', '53300.0', '50300.0',
#        '0.5', '0.65', '31.0', '131.0', '3.3', '8.5', '12.6', '3.6', '6.3',
#        '2.6', '1.2', '5.0', '26.0', '284.0', '263.0', '1160.0', '105.0',
#        '28300.0', '660.0', '26700.0', '4.1', '5.3', '17900.0', '337770.0',
#        '49140.0', '9260.0', '3990.0', '107.0', '476.0', '40000.0',
#        '6900.0', '5671.0', '2126.0', '13270.0', '1979.0', '6696.0',
#        '1227.0', '4494.0', '777.0', '31760.0', '2954.0', '15040.0',
#        '1303.0', '56000.0', '13150.0', '6650.0', '6490.0', '1655000.0',
#        '1593000.0', '2400.0', '48.0', '67.0', '1070.0', '4730.0',
#        '3010.0', '990.0'], dtype=object)

# %%
numeric = pd.to_numeric(df_bioactivity_data['standard_value'], errors='coerce')

min_value = numeric.min()

min_row = df_bioactivity_data[numeric == min_value]

min_value, min_row # check for min the standard_value (If we can inihibit by 50% with a lower concentration it means it has great power cuz we need less concentration to inhibit)
# Out:
# (-5.0,
#     action_type activity_comment  activity_id activity_properties  \
#  39        None             None      1606122                  []
#
#     assay_chembl_id                                  assay_description  \
#  39    CHEMBL856813  Concentration required to inhibit A beta 40 pe...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
#  39          B                    None                   None  BAO_0000190
#
#      ... target_organism         target_pref_name target_tax_id text_value  \
#  39  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
#
#      toid  type units    uo_units upper_value value
#  39  None  IC50     %  UO_0000187        None  -5.0
#
#  [1 rows x 46 columns])

# %%
df_bioactivity_data.to_csv('bioactivity_data.csv', index = False) #CSV FILE bioactivity data

# %%
import os
print(os.getcwd())
# Out:
# /Users/bm_castro/Desktop

# %% [markdown]
# # Preprocess Data 🧹

# %%
df_hmiss = df_bioactivity_data[df_bioactivity_data.standard_value.notna()] #missingvalues for the standard values and canonical smiles
df_hmiss = df_hmiss[df_bioactivity_data.canonical_smiles.notna()]
df_hmiss
# Out:
# /var/folders/9g/6_lvfzkn1f93tsfp09gqpz6c0000gn/T/ipykernel_4384/2449411064.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_hmiss = df_hmiss[df_bioactivity_data.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1598  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1599  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1600  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1601  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1602  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0          357577                                                 []
# 1          357580                                                 []
# 2          358965                                                 []
# 3          368887                                                 []
# 4          375954                                                 []
# ...           ...                                                ...
# 1598     25079667  [{'comments': None, 'relation': '=', 'result_f...
# 1599     25079668  [{'comments': None, 'relation': '=', 'result_f...
# 1600     25079669  [{'comments': None, 'relation': '=', 'result_f...
# 1601     25079670  [{'comments': None, 'relation': '=', 'result_f...
# 1602     25079671  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 1       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 2       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 3       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 4       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# ...              ...                                                ...
# 1598   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1599   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1600   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1601   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1602   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1598          B                    None                   None  BAO_0000190
# 1599          B                    None                   None  BAO_0000190
# 1600          B                    None                   None  BAO_0000190
# 1601          B                    None                   None  BAO_0000190
# 1602          B                    None                   None  BAO_0000190
#
#       ... target_organism         target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 2     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 3     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 4     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# ...   ...             ...                      ...           ...        ...
# 1598  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1599  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1600  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1601  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1602  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
#
#       toid  type units    uo_units upper_value value
# 0     None  IC50    uM  UO_0000065        None   5.0
# 1     None  IC50    uM  UO_0000065        None   2.7
# 2     None  IC50    uM  UO_0000065        None   1.8
# 3     None  IC50    uM  UO_0000065        None  11.0
# 4     None  IC50    uM  UO_0000065        None  10.0
# ...    ...   ...   ...         ...         ...   ...
# 1598  None  IC50    uM  UO_0000065        None  1.03
# 1599  None  IC50    uM  UO_0000065        None  0.99
# 1600  None  IC50    uM  UO_0000065        None   0.1
# 1601  None  IC50    uM  UO_0000065        None  1.56
# 1602  None  IC50    uM  UO_0000065        None  0.18
#
# [1427 rows x 46 columns]

# %%
len(df_hmiss.canonical_smiles.unique())
# Out:
# 1188

# %%
df_drop = df_hmiss.drop_duplicates(["canonical_smiles"])
df_drop
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1598  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1599  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1600  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1601  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1602  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0          357577                                                 []
# 1          357580                                                 []
# 2          358965                                                 []
# 3          368887                                                 []
# 4          375954                                                 []
# ...           ...                                                ...
# 1598     25079667  [{'comments': None, 'relation': '=', 'result_f...
# 1599     25079668  [{'comments': None, 'relation': '=', 'result_f...
# 1600     25079669  [{'comments': None, 'relation': '=', 'result_f...
# 1601     25079670  [{'comments': None, 'relation': '=', 'result_f...
# 1602     25079671  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 1       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 2       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 3       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 4       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# ...              ...                                                ...
# 1598   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1599   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1600   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1601   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1602   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1598          B                    None                   None  BAO_0000190
# 1599          B                    None                   None  BAO_0000190
# 1600          B                    None                   None  BAO_0000190
# 1601          B                    None                   None  BAO_0000190
# 1602          B                    None                   None  BAO_0000190
#
#       ... target_organism         target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 2     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 3     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 4     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# ...   ...             ...                      ...           ...        ...
# 1598  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1599  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1600  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1601  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1602  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
#
#       toid  type units    uo_units upper_value value
# 0     None  IC50    uM  UO_0000065        None   5.0
# 1     None  IC50    uM  UO_0000065        None   2.7
# 2     None  IC50    uM  UO_0000065        None   1.8
# 3     None  IC50    uM  UO_0000065        None  11.0
# 4     None  IC50    uM  UO_0000065        None  10.0
# ...    ...   ...   ...         ...         ...   ...
# 1598  None  IC50    uM  UO_0000065        None  1.03
# 1599  None  IC50    uM  UO_0000065        None  0.99
# 1600  None  IC50    uM  UO_0000065        None   0.1
# 1601  None  IC50    uM  UO_0000065        None  1.56
# 1602  None  IC50    uM  UO_0000065        None  0.18
#
# [1188 rows x 46 columns]

# %%
selection = ["molecule_chembl_id", "canonical_smiles", "standard_value"]
df_preprocessed = df_drop[selection]
df_preprocessed
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1598      CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1599      CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1600      CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1601      CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1602      CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#      standard_value
# 0            5000.0
# 1            2700.0
# 2            1800.0
# 3           11000.0
# 4           10000.0
# ...             ...
# 1598         1030.0
# 1599          990.0
# 1600          100.0
# 1601         1560.0
# 1602          180.0
#
# [1188 rows x 3 columns]

# %%
df_preprocessed.to_csv("bioactivity_data_preprocessed.csv", index = False) #store the file

# %% [markdown]
# ***

# %%
df_labeling = pd.read_csv("bioactivity_data_preprocessed.csv")

# %%
bioactivity_class = [] #labeling as active or inactive based on bioactivity data
for i in df_labeling.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append("inactive")
    elif float(i) <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermidiate")

# %%
df_labeling.molecule_chembl_id
# Out:
# 0        CHEMBL311039
# 1        CHEMBL450926
# 2        CHEMBL310242
# 3         CHEMBL74874
# 4         CHEMBL75183
#             ...
# 1183    CHEMBL5274298
# 1184    CHEMBL5283067
# 1185    CHEMBL5273520
# 1186    CHEMBL5282081
# 1187    CHEMBL5274654
# Name: molecule_chembl_id, Length: 1188, dtype: object

# %%
mol_cid = []
for i in df_labeling.molecule_chembl_id:
    mol_cid.append(i)

# %%
canonical_smiles = []
for i in df_labeling.canonical_smiles:
    canonical_smiles.append(i)

# %%
standard_value = []
for i in df_labeling.standard_value:
    standard_value.append(i)

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, standard_value, bioactivity_class,))
df_features = pd.DataFrame(data_tuples, columns=['mol_cid', 'canonical_smiles', 'standard_value', 'bioactivity_class'])
df_features
#new dataframe is structured to contain information about drug candidates (molecule IDs, chemical structures, bioactivity values, and bioactivity classes) that are being evaluated for their interaction with the Amyloid-beta A4 protein
# Out:
#             mol_cid                                   canonical_smiles  \
# 0      CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1      CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2      CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3       CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4       CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...             ...                                                ...
# 1183  CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1184  CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1185  CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1186  CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1187  CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value bioactivity_class
# 0             5000.0      intermidiate
# 1             2700.0      intermidiate
# 2             1800.0      intermidiate
# 3            11000.0          inactive
# 4            10000.0          inactive
# ...              ...               ...
# 1183          1030.0      intermidiate
# 1184           990.0            active
# 1185           100.0            active
# 1186          1560.0      intermidiate
# 1187           180.0            active
#
# [1188 rows x 4 columns]

# %%
df_features.to_csv('bioactivity_data_features_processed.csv', index = False)

# %%
df_features
# Out:
#             mol_cid                                   canonical_smiles  \
# 0      CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1      CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2      CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3       CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4       CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...             ...                                                ...
# 1183  CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1184  CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1185  CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1186  CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1187  CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value bioactivity_class
# 0             5000.0      intermidiate
# 1             2700.0      intermidiate
# 2             1800.0      intermidiate
# 3            11000.0          inactive
# 4            10000.0          inactive
# ...              ...               ...
# 1183          1030.0      intermidiate
# 1184           990.0            active
# 1185           100.0            active
# 1186          1560.0      intermidiate
# 1187           180.0            active
#
# [1188 rows x 4 columns]

# %% [markdown]
# ### Treat the smiles 👨🏻‍🔬: drop the canonical smile column? why? Canonical smiles might have multicomponent compounds, salts which are considered molecular fragments and they are separated by "." .
# - There is an assumption tho: Essentially these fragments are considered the smaller part of the structure thus, they will be discarded.
# - What remains is a list with the bigger fragment (the main and bigger structure)

# %%
df_drop_smiles = df_features.drop(columns='canonical_smiles')

# %%
smiles=[]

for i in df_features.canonical_smiles.to_list():
    fragment = str(i).split('.') #goes throught each smile converting into a string and splitting by "." (como explicado antes por causa dos fragmentos)
    fragment_long = max(fragment, key = len) #biggest fragment
    smiles.append(fragment_long) #added to smiles

smiles = pd.Series(smiles, name="canonical_smiles")

# %%
df_smiles_cleaned = pd.concat([df_drop_smiles, smiles], axis = 1) #all concatenated again cleaned
df_smiles_cleaned
# Out:
#             mol_cid  standard_value bioactivity_class  \
# 0      CHEMBL311039          5000.0      intermidiate
# 1      CHEMBL450926          2700.0      intermidiate
# 2      CHEMBL310242          1800.0      intermidiate
# 3       CHEMBL74874         11000.0          inactive
# 4       CHEMBL75183         10000.0          inactive
# ...             ...             ...               ...
# 1183  CHEMBL5274298          1030.0      intermidiate
# 1184  CHEMBL5283067           990.0            active
# 1185  CHEMBL5273520           100.0            active
# 1186  CHEMBL5282081          1560.0      intermidiate
# 1187  CHEMBL5274654           180.0            active
#
#                                        canonical_smiles
# 0             CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1       CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                                                 ...
# 1183  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1184  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1185  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1186  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1187  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
# [1188 rows x 4 columns]

# %% [markdown]
# ### 💊 Lipinski's "Rule of Five" is a set of guidelines used to evaluate the druglikeness of a compound, specifically for oral bioavailability. It assesses four main parameters that are important for drug absorption and distribution.
# - Molecular Weight: Should be less than 500 Daltons.
# - LogP (Octanol-water partition coefficient): Should be less than 5, indicating acceptable lipophilicity.
# - Hydrogen Bond Donors: Should be fewer than 5.
# - Hydrogen Bond Acceptors: Should be fewer than 10.

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) #Smiles sao strings que nao sao manipulaveis para calculaçoes (i.e molecularweight, logP...) entao
                                       # o que se faz é converter atraves da funçao MolFromSmiles os smiles/strings (elem) em "mol" Object para haver manipulaçao dos dados 
        moldata.append(mol)
       
    baseData= np.arange(1,1) #empty array
    i=0 #tracking number of iterations
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol) #usa descriptor module para calcular molweight e logp
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)# aqui usa o lipinski module
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   #adicionar tudo na mesma array
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])  #vai dando stack verticalmente adicionando novas rows
        i=i+1      
    # no final o que temos é uma array 2D onde cada row representa os descriptors de uma molecula (i.e: molecular weight.... de uma molecula (0=C=0...))
    #na verdade 
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df_smiles_cleaned.canonical_smiles)
df_lipinski
# Out:
#            MW     LogP  NumHDonors  NumHAcceptors
# 0     311.422  3.31880         1.0            2.0
# 1     299.461  3.24120         1.0            3.0
# 2     311.422  3.31880         1.0            2.0
# 3     327.877  3.83310         1.0            2.0
# 4     372.328  3.94220         1.0            2.0
# ...       ...      ...         ...            ...
# 1183  510.448 -0.85390         7.0           13.0
# 1184  680.640  4.43222         6.0           15.0
# 1185  624.620  5.52076         7.0           13.0
# 1186  552.491  4.81824         4.0           10.0
# 1187  556.479  3.48004         7.0           11.0
#
# [1188 rows x 4 columns]

# %%
df_features
# Out:
#             mol_cid                                   canonical_smiles  \
# 0      CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1      CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2      CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3       CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4       CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...             ...                                                ...
# 1183  CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1184  CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1185  CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1186  CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1187  CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value bioactivity_class
# 0             5000.0      intermidiate
# 1             2700.0      intermidiate
# 2             1800.0      intermidiate
# 3            11000.0          inactive
# 4            10000.0          inactive
# ...              ...               ...
# 1183          1030.0      intermidiate
# 1184           990.0            active
# 1185           100.0            active
# 1186          1560.0      intermidiate
# 1187           180.0            active
#
# [1188 rows x 4 columns]

# %%
df_combined = pd.concat([df_features, df_lipinski], axis = 1)

# %%
df_combined
# Out:
#             mol_cid                                   canonical_smiles  \
# 0      CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1      CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2      CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3       CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4       CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...             ...                                                ...
# 1183  CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1184  CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1185  CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1186  CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1187  CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value bioactivity_class       MW     LogP  NumHDonors  \
# 0             5000.0      intermidiate  311.422  3.31880         1.0
# 1             2700.0      intermidiate  299.461  3.24120         1.0
# 2             1800.0      intermidiate  311.422  3.31880         1.0
# 3            11000.0          inactive  327.877  3.83310         1.0
# 4            10000.0          inactive  372.328  3.94220         1.0
# ...              ...               ...      ...      ...         ...
# 1183          1030.0      intermidiate  510.448 -0.85390         7.0
# 1184           990.0            active  680.640  4.43222         6.0
# 1185           100.0            active  624.620  5.52076         7.0
# 1186          1560.0      intermidiate  552.491  4.81824         4.0
# 1187           180.0            active  556.479  3.48004         7.0
#
#       NumHAcceptors
# 0               2.0
# 1               3.0
# 2               2.0
# 3               2.0
# 4               2.0
# ...             ...
# 1183           13.0
# 1184           15.0
# 1185           13.0
# 1186           10.0
# 1187           11.0
#
# [1188 rows x 8 columns]

# %%
df_combined.shape
# Out:
# (1188, 8)

# %% [markdown]
# ### 🔢 Conversion of IC50 into pIC50
# - Convert nM to M (multiplying by 10^-9)
# - -log10(IC50)(negative logarithm)
# - Delete standard_value and create a pIC50 column.

# %%
df_combined.standard_value.describe() #podemos perceber pelo output que o numero é gigante. Se o numero for muito elevado na escala logaritimica ele fica negativo
                                    # entao temos de dar cap num certo valor
# Out:
# count    1.188000e+03
# mean     2.334128e+04
# std      8.556325e+04
# min     -1.000000e+00
# 25%      1.790000e+02
# 50%      3.865000e+03
# 75%      1.711750e+04
# max      1.655000e+06
# Name: standard_value, dtype: float64

# %% [markdown]
# ####Note: some large values need to be capped (fixed ate one number) otherwise they would become negative for Amyloide-beta A4

# %%
def norm_value(input):
    norm = []
    
    for i in input['standard_value']:
        if i > 1000000000:
            i=1000000000
        norm.append(i)
        
    input["standard_value_norm"] = norm
    x = input.drop("standard_value",axis=1)
    
    return x

# %%
import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        M = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(M))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', axis = 1)
        
    return x

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#             mol_cid                                   canonical_smiles  \
# 0      CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1      CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2      CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3       CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4       CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...             ...                                                ...
# 1183  CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1184  CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1185  CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1186  CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1187  CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#      bioactivity_class       MW     LogP  NumHDonors  NumHAcceptors  \
# 0         intermidiate  311.422  3.31880         1.0            2.0
# 1         intermidiate  299.461  3.24120         1.0            3.0
# 2         intermidiate  311.422  3.31880         1.0            2.0
# 3             inactive  327.877  3.83310         1.0            2.0
# 4             inactive  372.328  3.94220         1.0            2.0
# ...                ...      ...      ...         ...            ...
# 1183      intermidiate  510.448 -0.85390         7.0           13.0
# 1184            active  680.640  4.43222         6.0           15.0
# 1185            active  624.620  5.52076         7.0           13.0
# 1186      intermidiate  552.491  4.81824         4.0           10.0
# 1187            active  556.479  3.48004         7.0           11.0
#
#       standard_value_norm
# 0                  5000.0
# 1                  2700.0
# 2                  1800.0
# 3                 11000.0
# 4                 10000.0
# ...                   ...
# 1183               1030.0
# 1184                990.0
# 1185                100.0
# 1186               1560.0
# 1187                180.0
#
# [1188 rows x 8 columns]

# %%
df_pIC50 = pIC50(df_norm)
df_pIC50
# Out:
# /var/folders/9g/6_lvfzkn1f93tsfp09gqpz6c0000gn/T/ipykernel_4384/249768756.py:8: RuntimeWarning: invalid value encountered in log10
#   pIC50.append(-np.log10(M))
#             mol_cid                                   canonical_smiles  \
# 0      CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1      CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2      CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3       CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4       CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...             ...                                                ...
# 1183  CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1184  CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1185  CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1186  CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1187  CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#      bioactivity_class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0         intermidiate  311.422  3.31880         1.0            2.0  5.301030
# 1         intermidiate  299.461  3.24120         1.0            3.0  5.568636
# 2         intermidiate  311.422  3.31880         1.0            2.0  5.744727
# 3             inactive  327.877  3.83310         1.0            2.0  4.958607
# 4             inactive  372.328  3.94220         1.0            2.0  5.000000
# ...                ...      ...      ...         ...            ...       ...
# 1183      intermidiate  510.448 -0.85390         7.0           13.0  5.987163
# 1184            active  680.640  4.43222         6.0           15.0  6.004365
# 1185            active  624.620  5.52076         7.0           13.0  7.000000
# 1186      intermidiate  552.491  4.81824         4.0           10.0  5.806875
# 1187            active  556.479  3.48004         7.0           11.0  6.744727
#
# [1188 rows x 8 columns]

# %%
df_pIC50.pIC50.describe()
# Out:
# count    1187.000000
# mean        5.764696
# std         1.336165
# min         2.781202
# 25%         4.765613
# 50%         5.412289
# 75%         6.744727
# max         9.522879
# Name: pIC50, dtype: float64

# %%
df_pIC50.to_csv("bioactivity_data_pIC50.csv")

# %%
df_active_inactive = df_pIC50[df_pIC50['bioactivity_class'] != 'intermidiate'].reset_index(drop=True) #just 2 classes to make it easier
df_active_inactive
# Out:
#            mol_cid                                   canonical_smiles  \
# 0      CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 1      CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 2        CHEMBL563                   CC(C(=O)O)c1ccc(-c2ccccc2)c(F)c1
# 3     CHEMBL196279           CC(C(=O)O)c1ccc(-c2ccc(Cl)c(Cl)c2)c(F)c1
# 4     CHEMBL195970           CC(C(=O)O)c1ccc(-c2cc(Cl)cc(Cl)c2)c(F)c1
# ..             ...                                                ...
# 858  CHEMBL5290033  Cc1ccc(NCC[C@@H]2CCCN3CCCC[C@H]23)c2c(=O)c3ccc...
# 859  CHEMBL5283881  CC(C)C[C@H](NC(=O)[C@H](Cc1ccccc1)C[C@@H](O)[C...
# 860  CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 861  CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 862  CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#     bioactivity_class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0            inactive  327.877  3.83310         1.0            2.0  4.958607
# 1            inactive  372.328  3.94220         1.0            2.0  5.000000
# 2            inactive  244.265  3.68080         1.0            1.0  3.515700
# 3            inactive  313.155  4.98760         1.0            1.0  4.124939
# 4            inactive  313.155  4.98760         1.0            1.0  4.113509
# ..                ...      ...      ...         ...            ...       ...
# 858          inactive  390.527  5.32112         1.0            4.0  4.886057
# 859            active  671.879  5.56660         4.0            6.0  7.318759
# 860            active  680.640  4.43222         6.0           15.0  6.004365
# 861            active  624.620  5.52076         7.0           13.0  7.000000
# 862            active  556.479  3.48004         7.0           11.0  6.744727
#
# [863 rows x 8 columns]

# %% [markdown]
# ***

# %% [markdown]
# # Exploratory Data Analysis (EDA) (Chemical space analysis) 🧪

# %%
import seaborn as sns
sns.set_theme(style='ticks')
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,6))
sns.countplot(x="bioactivity_class", data=df_active_inactive, edgecolor = "black", palette= "Set2")

plt.xlabel("Bioactivity Class", fontsize = 14, fontweight = "bold")
plt.ylabel("Frequency", fontsize = 14, fontweight = "bold")
plt.title("Bioactivity Class Distribution", fontsize= 17, fontweight= "bold")

plt.xticks(fontsize = 12, fontweight= "bold")
plt.yticks(fontsize=12, fontweight = "bold")

plt.tight_layout()
plt.savefig("plot_bioactivity_class_distribution.pdf")

plt.show()

# %%
df_active_inactive['bioactivity_class'].value_counts()['active']

# %%
df_active_inactive['bioactivity_class'].value_counts()['inactive']

# %% [markdown]
# #### MW vs LogP (lets check for trends - clusters, liophility and molecularsize relation)

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x="MW", y="LogP", data=df_active_inactive, edgecolor = "black", palette= "Set2", size='pIC50', hue="bioactivity_class", alpha=0.8)

plt.xlabel("MW", fontsize = 14, fontweight = "bold")
plt.ylabel("logP", fontsize = 14, fontweight = "bold")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

plt.xticks(fontsize = 12, fontweight= "bold")
plt.yticks(fontsize=12, fontweight = "bold")

plt.tight_layout()
plt.savefig("plot_MW_logP.pdf")

plt.show()

# %% [markdown]
# ### Similar inactive and active cluster
# ### Inactive Compoundsare
# -   Generally dispersed across different areas.
# -   Main clustering occurs within the optimal Lipinski rule conditions.
# ### Active Compounds:
# - Form a well-defined cluster with minimal dispersion.
# - Cluster closely resembles that of inactive compounds.
# - LogP values for most are well-positioned below 5.
# - Molecular weight generally falls below 500 Daltons, though visibility could improve with more consistent adherence to this limit.

# %% [markdown]
# ### Boxplots de pIC50

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'pIC50', data = df_active_inactive, palette= "Set2")

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_pic50.pdf')

# %% [markdown]
# - Show some outliers, while the active compounds are consistent and well-behaved, indicating that the bioactivity thresholds we set (e.g., IC50 < 1000 implies pIC50 > 5) are effective.
# - The active compounds have notably higher pIC50 values compared to the inactive ones, which means they are more potent. This is due to the inverse relationship between IC50 and pIC50 values.

# %% [markdown]
# ### Mann-Whitney U test for the statistical analysis (normality distribution p<0.05 they are different)

# %%
def mannwhitney(descriptor, verbose=False):
  
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'bioactivity_class']
  df_man = df_active_inactive[selection]
  active = df_man[df_man['bioactivity_class'] == 'active']
  active = active[descriptor]

  selection = [descriptor, 'bioactivity_class']
  df_man = df_active_inactive[selection]
  inactive = df_man[df_man['bioactivity_class'] == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'
  
  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney("pIC50")

# %%
mannwhitney("MW")

# %%
mannwhitney("LogP")

# %%
mannwhitney("NumHDonors")

# %%
mannwhitney("NumHAcceptors")

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'MW', data = df_active_inactive, palette="Set2")

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'LogP', data = df_active_inactive, palette="Set2")

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'NumHDonors', data = df_active_inactive, palette="Set2")

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'NumHAcceptors', data = df_active_inactive, palette="Set2")

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')

# %% [markdown]
# ### Some conclusions must be adressed: there are outliers, everything is statistically different minus logP which can suggest that solubility might not be that important and maybe polar interactions are prefered (HDonors and Acceptors).

# %% [markdown]
# ***

# %% [markdown]
# # Generate Descriptors and Molecular Fingerprints 🐾 0️⃣ 1️⃣

# %%
import os
os.environ['PATH'] = '/opt/homebrew/bin:' + os.environ['PATH']

# %%
# !wget --version

# %%
# !wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# !wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh

# %%
! unzip padel.zip

# %%
df_pIC50

# %%
df_active_inactive

# %%
select = ['canonical_smiles', 'mol_cid']
df_select = df_pIC50[select]
df_select.to_csv("molecule.smi", sep='\t', index = False, header=False)

# %%
! cat molecule.smi | head -5

# %%
! cat molecule.smi | wc -l

# %% [markdown]
# ***

# %% [markdown]
# # PaDEL descriptor Software (java,homebrew....)

# %%
! cat padel.sh #Remove (NaCl), Present nitro groups,
#PubChem fingerprints  (Binary representations)

# %%
! bash padel.sh

# %%
! ls -l

# %% [markdown]
# - Essentially, each column in the dataframe represents a specific structural feature defined by PubChem (e.g., PubchemFP0 might indicate the presence of a certain type of ring structure). The values are binary, where "1" indicates the presence of that feature, and "0" indicates its absence

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # DL pipeline 🧠⃤

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score

# %% [markdown]
# # <span style="color: green;">1st - "df_DL": will be canonical_smiles & pIC50</span>

# %%
df_pIC50
# Out:
#             mol_cid                                   canonical_smiles  \
# 0      CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1      CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2      CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3       CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4       CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...             ...                                                ...
# 1183  CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1184  CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1185  CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1186  CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1187  CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#      bioactivity_class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0         intermidiate  311.422  3.31880         1.0            2.0  5.301030
# 1         intermidiate  299.461  3.24120         1.0            3.0  5.568636
# 2         intermidiate  311.422  3.31880         1.0            2.0  5.744727
# 3             inactive  327.877  3.83310         1.0            2.0  4.958607
# 4             inactive  372.328  3.94220         1.0            2.0  5.000000
# ...                ...      ...      ...         ...            ...       ...
# 1183      intermidiate  510.448 -0.85390         7.0           13.0  5.987163
# 1184            active  680.640  4.43222         6.0           15.0  6.004365
# 1185            active  624.620  5.52076         7.0           13.0  7.000000
# 1186      intermidiate  552.491  4.81824         4.0           10.0  5.806875
# 1187            active  556.479  3.48004         7.0           11.0  6.744727
#
# [1188 rows x 8 columns]

# %%
df_DL = df_pIC50[["canonical_smiles", "pIC50"]]
df_DL
# Out:
#                                        canonical_smiles     pIC50
# 0             CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1  5.301030
# 1       CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1  5.568636
# 2     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...  5.744727
# 3     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...  4.958607
# 4     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...  5.000000
# ...                                                 ...       ...
# 1183  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...  5.987163
# 1184  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...  6.004365
# 1185  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...  7.000000
# 1186  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...  5.806875
# 1187  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...  6.744727
#
# [1188 rows x 2 columns]

# %%
df_DL.isnull().sum()
# Out:
# canonical_smiles    0
# pIC50               1
# dtype: int64

# %%
df_DL["pIC50"] = df_DL["pIC50"].fillna(df_DL["pIC50"].median())
# Out:
# /var/folders/9g/6_lvfzkn1f93tsfp09gqpz6c0000gn/T/ipykernel_4384/3205064270.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_DL["pIC50"] = df_DL["pIC50"].fillna(df_DL["pIC50"].median())

# %%
df_DL.isnull().sum()
# Out:
# canonical_smiles    0
# pIC50               0
# dtype: int64

# %%
df_DL
# Out:
#                                        canonical_smiles     pIC50
# 0             CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1  5.301030
# 1       CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1  5.568636
# 2     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...  5.744727
# 3     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...  4.958607
# 4     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...  5.000000
# ...                                                 ...       ...
# 1183  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...  5.987163
# 1184  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...  6.004365
# 1185  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...  7.000000
# 1186  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...  5.806875
# 1187  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...  6.744727
#
# [1188 rows x 2 columns]

# %%
df_DL.duplicated().sum()
# Out:
# 0

# %%
Xdl = df_DL.drop("pIC50", axis=1)
Xdl
# Out:
#                                        canonical_smiles
# 0             CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1       CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4     CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                                                 ...
# 1183  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1184  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1185  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1186  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1187  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
# [1188 rows x 1 columns]

# %%
Ydl = df_DL["pIC50"]
Ydl
# Out:
# 0       5.301030
# 1       5.568636
# 2       5.744727
# 3       4.958607
# 4       5.000000
#           ...
# 1183    5.987163
# 1184    6.004365
# 1185    7.000000
# 1186    5.806875
# 1187    6.744727
# Name: pIC50, Length: 1188, dtype: float64

# %%
Xdl.shape, Ydl.shape
# Out:
# ((1188, 1), (1188,))

# %% [markdown]
# ### Final Train-Val-Test (64-16-20)%

# %%
Xdl_train, Xdl_test, Ydl_train, Ydl_test = train_test_split(Xdl, Ydl, test_size=0.2, random_state=42) #split into training and test 80/20

# %%
Xdl_train, Xdl_val, Ydl_train, Ydl_val = train_test_split(Xdl_train, Ydl_train, test_size=0.2, random_state=42) #inside 80% corresponding to raining, create a train and valiation set 80/20.

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color: Red;">2nd - "df_DL2": will be df_pIC50 with Descriptors but without the bioactivity class</span>  - Future Work

# %%
df_pIC50

# %%
df_DL2 = df_pIC50.drop(columns=["bioactivity_class"])
df_DL2

# %%
df_DL2.isnull().sum()

# %%
df_DL2["pIC50"] = df_DL2["pIC50"].fillna(df_DL2["pIC50"].median())

# %%
df_DL2.isnull().sum()

# %%
df_DL2.duplicated().sum()

# %%
Xdl2 = df_DL2.drop(columns="pIC50")
Xdl2

# %%
Ydl2 = df_pIC50["pIC50"]
Ydl2

# %%
Xdl2_train, Ydl2_train, Xdl2_test, Ydl2_test = train_test_split(Xdl2, Ydl2, test_size=0.2)

# %%
Xdl2.shape, Ydl2.shape

# %% [markdown]
# ***

# %% [markdown]
# # 📊 DL Approaches (SCRATCH) 📊
#
# - ✔️ Finetune ChemBERTa using it for a regression task: No LoRA
# - ✔️ Finetune ChemBERTa using it for a regression task : With LoRA

# %%
import mlflow
import mlflow.pytorch
import torch
import pandas as pd
from transformers import TrainingArguments, Trainer, AutoTokenizer, AutoModelForSequenceClassification
from datasets import Dataset
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ***

# %% [markdown]
# ## No LoRA pipeline 🐌

# %% [markdown]
# ### Adjustments in the data 📙

# %%
print(torch.backends.mps.is_available())

# %%
# !pip show torch

# %%
print(f"Type of Xdl_train: {type(Xdl_train)}") #Xdl is a dataframe and Ydl is a series so we have to trasnform into a 1D array in order to manage better the dataset
print(f"Type of Ydl_train: {type(Ydl_train)}")

# %%
Xdl_train_flat = Xdl_train.squeeze()
Xdl_test_flat = Xdl_test.squeeze()
Xdl_val_flat = Xdl_val.squeeze() #All series

# %%
train_dfdl_real = pd.concat([Xdl_train, Ydl_train], axis=1)
test_dfdl_real = pd.concat([Xdl_test, Ydl_test], axis=1)
val_dfdl_real = pd.concat([Xdl_val, Ydl_val], axis=1)

# %%
train_dfdl_real

# %%
type(train_dfdl_real)
train_dfdl_real

# %%
print("Train Dataset: {}".format(train_dfdl_real.shape))
print("Eval Dataset: {}".format(test_dfdl_real.shape))
print("TEST Dataset: {}".format(val_dfdl_real.shape)) #frame and not series finally

# %% [markdown]
# ### Preparing Dataset for HuggingFace ecossystem 📙

# %%
from datasets import Dataset

train_dataset = Dataset.from_pandas(train_dfdl_real)
test_dataset = Dataset.from_pandas(test_dfdl_real)
val_dataset = Dataset.from_pandas(val_dfdl_real)

# %%
train_dataset = train_dataset.rename_column("pIC50", "labels") #Gotta rename tho labels so trainer can calculate the loss
val_dataset = val_dataset.rename_column("pIC50", "labels")
test_dataset = test_dataset.rename_column("pIC50", "labels")

# %% [markdown]
# ### DL MLFlow Tracking 🧾

# %%
mlflow.set_experiment("amyloydbeta-A4 ML")
mlflow.start_run(run_name="NoLora Chmebert") #no with statement

# %%
mlflow.set_tag("model", "ChemBERTa-zinc-base-v1")

# %% [markdown]
# ### Set Tokenization and Model loading 🤗 (replicates HuggingFace logo)

# %%
from transformers import RobertaTokenizer, RobertaForSequenceClassification, AutoTokenizer, AutoModelForSequenceClassification, BertTokenizer, BertForSequenceClassification
#Although Roberta is here, Autotokenizer is more of a flexible approach since it can call Roberta properties or BERT properties or Destil propertis etc..

# Load the ChemBERTa tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("seyonec/ChemBERTa-zinc-base-v1")

# Since this is a regression task, we will use a model for sequence classification and set the number of labels to 1
model = AutoModelForSequenceClassification.from_pretrained("seyonec/ChemBERTa-zinc-base-v1", num_labels=1) #numlabels=1 directs the task to a regression purpose. This pre-trained model was actually built for classification purposes and
#that is the reason why the output says that some weights can not be initialized essentially by defining num_labels=1 softmaxfunction in the head is removed

# %% [markdown]
# ### Tokenize the smiles correctly 😎 Tokenization of the canonical_SMILES

# %%
from transformers import DataCollatorWithPadding


def tokenize_function(examples):
    return tokenizer(examples["canonical_smiles"], padding="max_length", truncation=True, return_tensors="pt") #truncation=True and padding ensures that sequences longer than the specified max_length  are truncated, preventing overly long sequences from consuming too much memory.

# Tokenize datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)#tokenize both smiles on all the datasets "labels" are not touched simultineously by using batched = true

# %%
# Set the format of the dataset to be compatible with PyTorch
train_dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
val_dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
test_dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])

# %% [markdown]
# ### Train the model 🦾

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = predictions.flatten() #regression purposes cuz normally we got a tensor shape for classification like(batch, num_labels) but here it is a regression so (batch, 1) is appropriate
    mse = mean_squared_error(labels, predictions)
    r2 = r2_score(labels, predictions)

    mlflow.log_metric("eval_mse", mse)
    mlflow.log_metric("eval_r2", r2)
    
    return {"mse": mse, "r2": r2}

# %%
# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=8, #paralellism
    per_device_eval_batch_size=8,
    num_train_epochs=5,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=10,
    eval_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=2,
    load_best_model_at_end=True #Load the best performance
    report_to="none",# dont report to weight and biases nor tensorboard (personal desktop)
)

mlflow.log_param("learning_rate", 3e-5)
mlflow.log_param("num_epoch_train_epochs", 5)
mlflow.log_param("logging_steps", 10)
mlflow.log_param("weight_decay", 0.01)

# Define training arguments
#training_args = TrainingArguments(
#    output_dir="./results",
#    learning_rate=3e-5, #small, slow approach just to make sure
#    per_device_train_batch_size=8,
#    per_device_eval_batch_size=8, #process 8 samples before updating 
#    logging_dir='./logs',
#    logging_steps=10, #tracking over "10 steps"
#    eval_strategy="epoch",
#    save_strategy="epoch",
#    no_cuda=False,  # Set False we dont want CPU usage
#    use_mps_device=True  # Enable MPS backend for M1 GPU support as it is available  (checked in the beggining of the pipeline)


# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset, #training
    eval_dataset=val_dataset, #validation
    compute_metrics=compute_metrics
)

# %%
train_result= trainer.train()

mlflow.log_metric("train_loss", train_result.training_loss)

# %%
test_results = trainer.evaluate(test_dataset)
print(test_results)

mlflow.log_metric("test_loss", test_results)

# %%
mlflow.pytorch.log_model(trainer.model, "model")

# End the MLflow run
mlflow.end_run()

# %% [markdown]
# # 💡 Improvements 💡

# %% [markdown]
# - 💻 More computational power (can't rerun this)
# - 📈 Bigger dataset
# - ⚙️ Experiment with a model that is tailored for regression and other versions of chemberta
# - ⏳ Finetune the hyperparameters during training:
# specify torch specific parameters: bf16=True; torch_compile=True; optim= "adamw_torch_fused" (thats an adam optimizer but better (apex project) which is better than default)
# Experiment hyperparameter tuning (bigger batch, improve learningrate, increase unstability of gradient_norm during training)
#
# - 💭 Combine the dataset of canonical smiles with descriptors and fingerprints

# %% [markdown]
# ***

# %% [markdown]
# ### LoRA 🤗🎯

# %%
import mlflow
import mlflow.pytorch
import torch
import pandas as pd
from transformers import TrainingArguments, Trainer, AutoTokenizer, AutoModelForSequenceClassification
from datasets import Dataset
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Set the experiment and start the run
#mlflow.set_experiment("AmyloidBeta-A4 ML")
#run_name = "ChemBERTa LoRA Fine-tuning"
#mlflow.start_run(run_name=run_name)

# %%
mlflow.set_tag("base_model", "ChemBERTa-zinc-base-v1")
mlflow.set_tag("fine_tuning_strategy", "LoRA")

# %%
# Assuming Xdl_train, Ydl_train, etc., are already prepared pandas DataFrames (see the pipeline with no LoRA)
train_dfdl_real = pd.concat([Xdl_train, Ydl_train], axis=1)
test_dfdl_real = pd.concat([Xdl_test, Ydl_test], axis=1)
val_dfdl_real = pd.concat([Xdl_val, Ydl_val], axis=1)

# %%
train_dfdl_real
# Out:
#                                        canonical_smiles     pIC50
# 343   c1ccc2c(NCCSSCCNc3c4c(nc5ccccc35)CCCC4)c3c(nc2...  4.616185
# 1013            CN(C)CCCOc1ccc(/C=C/c2cc(=O)c(O)co2)cc1  5.345823
# 46    CCC[C@H](C(N)=O)[C@@H](CC(C)C)C(=O)N[C@H]1CCCC...  6.795880
# 238                   Cn1ncc2cc(-c3nc4ccc(F)nc4o3)ccc21  7.312471
# 106   CC[C@@H]1CCC[C@H](C2(OC(=O)N3CCC(O)(CC)CC3)CC2...  8.494850
# ...                                                 ...       ...
# 706   O=S(=O)(c1ccc(Cl)cc1)[C@@]12CCCC3(COC3)[C@@H]1...  7.995679
# 62    O=C(OCC1CCc2ccccc2N1S(=O)(=O)c1ccc(Cl)cc1)N1CC...  7.136677
# 230   O=C(/C=C/c1ccc(O)c(O)c1)O[C@@H]1C[C@](O)(C(=O)...  6.522879
# 946        CC1=C(/C=C/C(C)=C/C=C/C(C)=C/C=O)C(C)(C)CCC1  6.744727
# 256      COc1ccc2cc(C(=O)CN3CCN(c4ncccn4)CC3)c(=O)oc2c1  5.397940
#
# [760 rows x 2 columns]

# %%
train_dataset = Dataset.from_pandas(train_dfdl_real)
test_dataset = Dataset.from_pandas(test_dfdl_real)
val_dataset = Dataset.from_pandas(val_dfdl_real)

# %%
train_dataset

# %%
train_dataset = train_dataset.rename_column("pIC50", "labels")
val_dataset = val_dataset.rename_column("pIC50", "labels")
test_dataset = test_dataset.rename_column("pIC50", "labels")

# %%
train_dataset

# %%
train_dataset = train_dataset.rename_column("canonical_smiles", "text")
val_dataset = val_dataset.rename_column("canonical_smiles", "text")
test_dataset = test_dataset.rename_column("canonical_smiles", "text")

# %%
train_dataset

# %%
train_dataset = train_dataset.remove_columns(['__index_level_0__'])
val_dataset = val_dataset.remove_columns(['__index_level_0__'])
test_dataset = test_dataset.remove_columns(['__index_level_0__'])

# %%
train_dataset

# %%
from peft import get_peft_model, LoraConfig

# %%
# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("seyonec/ChemBERTa-zinc-base-v1")
model = AutoModelForSequenceClassification.from_pretrained("seyonec/ChemBERTa-zinc-base-v1", num_labels=1)
# Modify the classification head to be a regression head, althouhg num_labels already does that theoretically
  #just to make sure a regression head is being made

# Log model info
#mlflow.log_param("num_labels", 1)

# Configure LoRA
lora_config = LoraConfig(
    r=8,  # Low rank value (how many parameters are for finetuning) 
    lora_alpha=32,  # Scaling parameter 
    target_modules=["query"],  # Target final dense layer (classification head or in this case the regression) can be interesting (in this case idk). 
    lora_dropout=0.05,  # Dropout for LoRA; adds regularization 
    bias="none"
)

# Apply LoRA to the model
model = get_peft_model(model, lora_config)

# Log LoRA Configuration
#mlflow.log_param("lora_rank", lora_config.r)
#mlflow.log_param("lora_alpha", lora_config.lora_alpha)
#mlflow.log_param("lora_dropout", lora_config.lora_dropout)
#mlflow.log_param("target_modules", lora_config.target_modules)
# Out:
# /Users/bm_castro/miniconda3/envs/bioinf-env/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at seyonec/ChemBERTa-zinc-base-v1 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'
# /Users/bm_castro/miniconda3/envs/bioinf-env/lib/python3.8/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "

# %%
print("Problem Type:", model.config.problem_type)

# %%
print(model) #it would be interesting to target modules to query,key,value

# %%
def tokenize_function(examples):
    return tokenizer(examples["text"], padding=True, truncation=True, max_length=128)

train_datasett = train_dataset.map(tokenize_function, batched=True)
val_datasett = val_dataset.map(tokenize_function, batched=True)
test_datasett = test_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/760 [00:00<?, ? examples/s]
# Map:   0%|          | 0/190 [00:00<?, ? examples/s]
# Map:   0%|          | 0/238 [00:00<?, ? examples/s]

# %%
train_datasett

# %%
# Set the dataset format for PyTorch
train_datasett.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
val_datasett.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
test_datasett.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])

# %%
train_dataset

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def compute_metrics(eval_pred):
    print("compute_metrics function is called")
    predictions, labels = eval_pred
    
    # Ensure predictions and labels are numpy arrays
    predictions = np.array(predictions)
    labels = np.array(labels)
    
    # Print shapes for debugging
    print(f"Shape of predictions before flattening: {predictions.shape}")
    print(f"Shape of labels before flattening: {labels.shape}")
    
    # Flatten the arrays to make sure they are 1D
    predictions = predictions.flatten()
    labels = labels.flatten()
    
    # Print shapes after flattening for debugging
    print(f"Shape of predictions after flattening: {predictions.shape}")
    print(f"Shape of labels after flattening: {labels.shape}")
    
    # Print a few sample values from predictions and labels for further debugging
    print(f"Sample predictions: {predictions[:5]}")
    print(f"Sample labels: {labels[:5]}")
    
    # Calculate the metrics
    eval_mse = mean_squared_error(labels, predictions)
    r2 = r2_score(labels, predictions)
    
    # Return the metrics as a dictionary
    return {"eval_mse": eval_mse, "r2": r2}

"""def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = predictions.flatten()
    eval_mse = mean_squared_error(labels, predictions)
    r2 = r2_score(labels, predictions)

    #mlflow.log_metric("eval_mse", eval_mse)
    #mlflow.log_metric("eval_r2", r2)
    
    return {"eval_mse": eval_mse, "r2": r2}"""

# %%
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=5,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=10,
    save_strategy="epoch",
    save_total_limit=2,  
    load_best_model_at_end=False,
    greater_is_better=False,
)

# Log the training arguments
#mlflow.log_param("learning_rate", 3e-5)
#mlflow.log_param("num_epochs", 5)
#mlflow.log_param("batch_size", 8)
#mlflow.log_param("weight_decay", 0.01)



# Initialize the Trainer
trainerlora = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_datasett,
    eval_dataset=val_datasett,
    compute_metrics=compute_metrics
)

# %%
train_result= trainerlora.train()

#mlflow.log_metric("train_loss", train_result.training_loss)

# %%
# Evaluate on test dataset
test_result = trainerlora.evaluate(test_datasett)
mlflow.log_metric("test_eval_mse", test_result["eval_mse"])
mlflow.log_metric("test_r2", test_result["r2"])

# %% [markdown]
# ***

# %% [markdown]
# ### QLora 🤗🎯🎯- Future Work
# - gptq troubles with Mac 💻

# %%
# !pip install auto-gptq
# !pip install optimum
# !pip install bitsandbytes
